# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-AMN/Projetos/blob/main/ProcessoSeletivoBix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as plt

# %%
vendas = pd.read_csv("/content/Base de Dados - Questionário.xlsx - Sheet1.csv",decimal=',')
produtos = pd.read_csv("/content/Base de Dados - Questionário.xlsx - Sheet2.csv")
consumidores = pd.read_csv("/content/Base de Dados - Questionário.xlsx - Sheet3.csv")
lojas = pd.read_csv("/content/Base de Dados - Questionário.xlsx - Sheet4.csv")

# %%
vendas.head()
# Out:
#    Unnamed: 0  Unnamed: 1                        Unnamed: 2  \
# 0         NaN         NaN                               NaN
# 1         NaN         NaN                               NaN
# 2         NaN         NaN                               NaN
# 3         NaN         NaN                                ID
# 4         NaN         NaN  80260d682079b6090c8285b398c50d97
#
#                           Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                                NaN        NaN        NaN        NaN
# 1                                NaN        NaN        NaN        NaN
# 2                                NaN        NaN        NaN        NaN
# 3                          ProductID   ClientID   Discount  UnitPrice
# 4  002552c0663708129c0019cc97552d7d3      14001       0,08      249,2
#
#   Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0        NaN        NaN         NaN
# 1        NaN        NaN         NaN
# 2        NaN        NaN         NaN
# ...

# %%
vendaslimpo = vendas.drop(columns=['Unnamed: 0', 'Unnamed: 1'])

# %%
vendaslimpo
# Out:
#                              Unnamed: 2                         Unnamed: 3  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                    ID                          ProductID
# 4      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# ...                                 ...                                ...
# 32752  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32753  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32754  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32755  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32756  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
# ...

# %%
vendaslimpo = vendaslimpo.rename(columns=vendaslimpo.iloc[3])

# %%
vendaslimpo = vendaslimpo.drop(index =[0,1,2,3])

# %%
vendaslimpas = vendaslimpo.reset_index(drop = True)

# %%
vendaslimpas
# Out:
#                                      ID                          ProductID  \
# 0      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32748  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32749  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32752  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
#       ClientID Discount UnitPrice Quantity StoreID        Date
# ...

# %%
vendaslimpas.head()
# Out:
#                                  ID                          ProductID  \
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
#
#   ClientID Discount UnitPrice Quantity StoreID        Date
# 0    14001     0,08     249,2        1       4  12/10/2018
# 1    14001      0,1     162,4        1       4   4/25/2019
# 2    14001      0,1     194,6        1       4   7/17/2019
# 3    14002      0,1     201,6        2       1   4/10/2018
# 4    14002      0,1       406        1       1   1/21/2019

# %%
vendaslimpas["Discount"]= vendaslimpas["Discount"].str.replace(',','.')
vendaslimpas["UnitPrice"]= vendaslimpas["UnitPrice"].str.replace(',','.')

# %%
vendaslimpas = vendaslimpas.astype({'UnitPrice': float, 'Discount': float, 'Quantity' : int})

# %%
vendaslimpas["DiscountValue"] = vendaslimpas["UnitPrice"] * vendaslimpas["Discount"]

# %%
vendaslimpas
# Out:
#                                      ID                          ProductID  \
# 0      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32748  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32749  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32752  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
#       ClientID  Discount  UnitPrice  Quantity StoreID        Date  \
# ...

# %%
vendaslimpas["SalePrice"] = (vendaslimpas["UnitPrice"] - vendaslimpas["DiscountValue"]) * vendaslimpas["Quantity"]

# %%
vendaslimpas
# Out:
#                                      ID                          ProductID  \
# 0      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32748  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32749  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32752  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
#       ClientID  Discount  UnitPrice  Quantity StoreID        Date  \
# ...

# %%
ReceitaLiquida = vendaslimpas[['SalePrice','Date']]

# %%
ReceitaLiquida['Date'] = pd.to_datetime(ReceitaLiquida['Date'])
# Out:
# <ipython-input-18-9ae80854f85b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ReceitaLiquida['Date'] = pd.to_datetime(ReceitaLiquida['Date'])

# %%
ReceitaLiquida['Year'] = ReceitaLiquida['Date'].dt.year
# Out:
# <ipython-input-19-1acb9231b538>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ReceitaLiquida['Year'] = ReceitaLiquida['Date'].dt.year

# %%
ReceitaLiquida2019 = ReceitaLiquida.drop('Date', axis = 1)

# %%
ReceitaLiquida2019['Year'].value_counts()
# Out:
# 2018    17254
# 2019    14768
# 2020      731
# Name: Year, dtype: int64

# %%
ReceitaLiquida2019 = ReceitaLiquida2019.astype({'Year': int})

# %%
ReceitaLiquida2019 = ReceitaLiquida2019.loc[ReceitaLiquida2019['Year'] == 2019]

# %%
ReceitaLiquida2019.describe()
# Out:
#           SalePrice     Year
# count  14768.000000  14768.0
# mean     239.110315   2019.0
# std      155.245294      0.0
# min      103.320000   2019.0
# 25%      146.160000   2019.0
# 50%      192.780000   2019.0
# 75%      229.320000   2019.0
# max     1262.240000   2019.0

# %%
prodfreq = vendaslimpas['ProductID'].value_counts()

# %%
prodfreq['002d4ea7c04739c130bb74d7e7cd16943']
# Out:
# 963

# %%
consumidores.head()
# Out:
#       ID            City State DateOfBirth     Sex
# 0  14001        Curitiba    PR   6/28/1985   Homem
# 1  14002   Florianópolis    SC   1/10/1987   Homem
# 2  14003  Rio de Janeiro    RJ   11/5/1979   Homem
# 3  14004  Rio de Janeiro    RJ  11/25/1983  Mulher
# 4  14005   Florianópolis    SC    4/7/1969   Homem

# %%
consumidores['State'].value_counts()
# Out:
# SC    3459
# RJ    2844
# RS    2554
# PR    2132
# SP    1509
# MG     763
# BH     352
# ES       7
# MT       6
# MA       4
# RO       4
# GO       3
# BA       3
# RN       3
# AC       3
# RR       2
# PA       1
# MS       1
# Name: State, dtype: int64

# %%
lojas.head()
# Out:
#    ID            Name State
# 0   1   Florianópolis    SC
# 1   2  Rio de Janeiro    RJ
# 2   3    Porto Alegre    RS
# 3   4        Curitiba    PR
# 4   7       São Paulo    SP

# %%
produtos
# Out:
#                                    ID             Name Size
# 0   00066f42aeeb9f3007548bb9d3f33c381  Capitão América    P
# 1   00066f42aeeb9f3007548bb9d3f33c382  Capitão América    M
# 2   00066f42aeeb9f3007548bb9d3f33c383  Capitão América    G
# 3   00088930e925c41fd95ebfe695fd26551             Thor    P
# 4   00088930e925c41fd95ebfe695fd26552             Thor    M
# ..                                ...              ...  ...
# 68  0030e635639c898b323826589761cf233       Rick Morty    G
# 69  003128f981470c3e5a2e7445e4a771cd1   Homer Simpsons    P
# 70  003128f981470c3e5a2e7445e4a771cd2   Homer Simpsons    M
# 71  003128f981470c3e5a2e7445e4a771cd3   Homer Simpsons    G
# 72  003128f981470c3e5a2e7445e4a771cd4   Homer Simpsons   GG
#
# [73 rows x 3 columns]

# %%
produtos.head()
# Out:
#                                   ID             Name Size
# 0  00066f42aeeb9f3007548bb9d3f33c381  Capitão América    P
# 1  00066f42aeeb9f3007548bb9d3f33c382  Capitão América    M
# 2  00066f42aeeb9f3007548bb9d3f33c383  Capitão América    G
# 3  00088930e925c41fd95ebfe695fd26551             Thor    P
# 4  00088930e925c41fd95ebfe695fd26552             Thor    M

# %%
produtos.describe()
# Out:
#                                        ID            Name Size
# count                                  73              73   73
# unique                                 73              24    4
# top     00066f42aeeb9f3007548bb9d3f33c381  Homer Simpsons    P
# freq                                    1               4   24

# %%
completo = pd.merge(produtos,vendaslimpas,'outer')

# %%
completo
# Out:
#                                       ID             Name Size  \
# 0      00066f42aeeb9f3007548bb9d3f33c381  Capitão América    P
# 1      00066f42aeeb9f3007548bb9d3f33c382  Capitão América    M
# 2      00066f42aeeb9f3007548bb9d3f33c383  Capitão América    G
# 3      00088930e925c41fd95ebfe695fd26551             Thor    P
# 4      00088930e925c41fd95ebfe695fd26552             Thor    M
# ...                                  ...              ...  ...
# 32821   b155e2a8589d40bc9c0381ee48e3204f              NaN  NaN
# 32822   abb71d0110c4be1a1a0c52f929cab4a3              NaN  NaN
# 32823   db9a034f34174edd577b9f64cc982952              NaN  NaN
# 32824   ee00fa5093eb96d8573403b382fb60a8              NaN  NaN
# 32825   56c87d433bb46c7862e35e791b1907fa              NaN  NaN
#
#                                ProductID ClientID  Discount  UnitPrice  \
# 0                                    NaN      NaN       NaN        NaN
# ...
